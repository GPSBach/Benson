# %% [markdown]
# Load in data from turnstile file

# %%
# import libraries
import pandas as pd
import numpy as np

# set display options
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 30)

# load data
data_raw_sept22 = pd.read_csv('./data/turnstile_180922.txt')

# %%
data_raw_sept22.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/15/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/15/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/15/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/15/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/15/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6759219
# 1  REGULAR  6759234
# 2  REGULAR  6759251
# 3  REGULAR  6759330
# 4  REGULAR  6759538
#
#    EXITS
# 0                                            2291425
# 1                                            2291429
# 2                                            2291453
# 3                                            2291532
# 4                                            2291574
